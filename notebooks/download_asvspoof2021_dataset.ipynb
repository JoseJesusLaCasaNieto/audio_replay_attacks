# %% [markdown]
# # Download ASVspoof 2021 Dataset

# %% [markdown]
# ## 0. Libraries

# %%
import os
import requests
import zipfile

# %% [markdown]
# ## 1. Get setup

# %%
# Base path to store the data
DATA_DIR = "../data/raw"  # Ensure this folder exists

# URL of the training set
TRAINING_URL = "https://zenodo.org/records/4834716/files/ASVspoof2021_PA_eval_part06.tar.gz?download=1"
ARCHIVE_NAME = "ASVspoof2021.zip"

# %% [markdown]
# ## 2. Functions to download and extract data

# %%
# Function to download the file
def download_file(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    file_path = os.path.join(dest_folder, ARCHIVE_NAME)
    
    # Download the file if it doesn't exist already
    if not os.path.exists(file_path):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f"Download complete: {file_path}")
    else:
        print(f"The file already exists at {file_path}")
    
    return file_path

# %%
# Function to extract the zip file
def extract_zip(archive_path, extract_to):
    with zipfile.ZipFile(archive_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Data extracted to {extract_to}")
    
    os.remove(archive_path)
    print(f"File zip {archive_path} removed")

# %% [markdown]
# ## 3. Download and extract the data

# %%
# Download and extract the training set
archive_path = download_file(TRAINING_URL, DATA_DIR)
extract_zip(archive_path, DATA_DIR)
# Out:
# Downloading https://zenodo.org/records/4834716/files/ASVspoof2021_PA_eval_part06.tar.gz?download=1...
# Download complete: ../data/raw\ASVspoof2021.zip
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Download and extract the training set
#       2 archive_path = download_file(TRAINING_URL, DATA_DIR)
# ----> 3 extract_zip(archive_path, DATA_DIR)
#
# Cell In[4], line 3, in extract_zip(archive_path, extract_to)
#       2 def extract_zip(archive_path, extract_to):
# ----> 3     with zipfile.ZipFile(archive_path, 'r') as zip_ref:
#       4         zip_ref.extractall(extract_to)
#       5         print(f"Data extracted to {extract_to}")
#
# File c:\Users\placasa\AppData\Local\miniconda3\envs\replay_attacks\Lib\zipfile.py:1313, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1311 try:
#    1312     if mode == 'r':
# -> 1313         self._RealGetContents()
#    1314     elif mode in ('w', 'x'):
#    1315         # set the modified flag so central directory gets written
#    1316         # even if no files are added to the archive
#    1317         self._didModify = True
#
# File c:\Users\placasa\AppData\Local\miniconda3\envs\replay_attacks\Lib\zipfile.py:1380, in ZipFile._RealGetContents(self)
#    1378     raise BadZipFile("File is not a zip file")
#    1379 if not endrec:
# -> 1380     raise BadZipFile("File is not a zip file")
#    1381 if self.debug > 1:
#    1382     print(endrec)
#
# BadZipFile: File is not a zip file
