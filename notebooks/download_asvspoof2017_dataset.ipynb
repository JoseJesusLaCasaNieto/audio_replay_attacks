# %% [markdown]
# # Download Training Data ASVspoof 2017

# %% [markdown]
# ## 0. Libraries

# %%
import os
import requests
import zipfile

# %% [markdown]
# ## 1. Get setup

# %%
# Base path to store the data
DATA_DIR = "../data/raw"  # Ensure this folder exists

# URL of the training set
TRAINING_URL = "https://datashare.ed.ac.uk/bitstream/handle/10283/3055/ASVspoof2017_V2_train.zip?sequence=10&isAllowed=y"
ARCHIVE_NAME = "ASVspoof2017_V2_train.zip"

# %% [markdown]
# ## 2. Functions to download and extract data

# %%
# Function to download the file
def download_file(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    file_path = os.path.join(dest_folder, ARCHIVE_NAME)
    
    # Download the file if it doesn't exist already
    if not os.path.exists(file_path):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f"Download complete: {file_path}")
    else:
        print(f"The file already exists at {file_path}")
    
    return file_path

# %%
# Function to extract the zip file
def extract_zip(archive_path, extract_to):
    with zipfile.ZipFile(archive_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Data extracted to {extract_to}")
    
    os.remove(archive_path)
    print(f"File zip {archive_path} removed")

# %% [markdown]
# ## 3. Download and extract the data

# %%
# Download and extract the training set
archive_path = download_file(TRAINING_URL, DATA_DIR)
extract_zip(archive_path, DATA_DIR)
# Out:
# ...
# Download complete: ../data/raw\ASVspoof2017_V2_train.zip
# Data extracted to ../data/raw
# File zip ../data/raw\ASVspoof2017_V2_train.zip removed

# %% [markdown]
# # Download Develop Data ASVspoof 2017

# %% [markdown]
# ## 0. Libraries

# %%
import os
import requests
import zipfile

# %% [markdown]
# ## 1. Get setup

# %%
# Base path to store the data
DATA_DIR = "../data/raw"  # Ensure this folder exists

# URL of the training set
TRAINING_URL = "https://datashare.ed.ac.uk/bitstream/handle/10283/3055/ASVspoof2017_V2_dev.zip?sequence=5&isAllowed=y"
ARCHIVE_NAME = "ASVspoof2017_V2_develop.zip"

# %% [markdown]
# ## 2. Functions to download and extract data

# %%
# Function to download the file
def download_file(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    file_path = os.path.join(dest_folder, ARCHIVE_NAME)
    
    # Download the file if it doesn't exist already
    if not os.path.exists(file_path):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f"Download complete: {file_path}")
    else:
        print(f"The file already exists at {file_path}")
    
    return file_path

# %%
# Function to extract the zip file
def extract_zip(archive_path, extract_to):
    with zipfile.ZipFile(archive_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Data extracted to {extract_to}")
    
    os.remove(archive_path)
    print(f"File zip {archive_path} removed")

# %% [markdown]
# ## 3. Download and extract the data

# %%
# Download and extract the training set
archive_path = download_file(TRAINING_URL, DATA_DIR)
extract_zip(archive_path, DATA_DIR)
# Out:
# ...
# Download complete: ../data/raw\ASVspoof2017_V2_develop.zip
# Data extracted to ../data/raw
# File zip ../data/raw\ASVspoof2017_V2_develop.zip removed

# %% [markdown]
# # Download Eval Data ASVspoof 2017

# %% [markdown]
# ## 0. Libraries

# %%
import os
import requests
import zipfile

# %% [markdown]
# ## 1. Get setup

# %%
# Base path to store the data
DATA_DIR = "../data/raw"  # Ensure this folder exists

# URL of the training set
TRAINING_URL = "https://datashare.ed.ac.uk/bitstream/handle/10283/3055/ASVspoof2017_V2_eval.zip?sequence=6&isAllowed=y"
ARCHIVE_NAME = "ASVspoof2017_V2_eval.zip"

# %% [markdown]
# ## 2. Functions to download and extract data

# %%
# Function to download the file
def download_file(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    file_path = os.path.join(dest_folder, ARCHIVE_NAME)
    
    # Download the file if it doesn't exist already
    if not os.path.exists(file_path):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f"Download complete: {file_path}")
    else:
        print(f"The file already exists at {file_path}")
    
    return file_path

# %%
# Function to extract the zip file
def extract_zip(archive_path, extract_to):
    with zipfile.ZipFile(archive_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Data extracted to {extract_to}")
    
    os.remove(archive_path)
    print(f"File zip {archive_path} removed")

# %% [markdown]
# ## 3. Download and extract the data

# %%
# Download and extract the training set
archive_path = download_file(TRAINING_URL, DATA_DIR)
extract_zip(archive_path, DATA_DIR)
# Out:
# ...
# Download complete: ../data/raw\ASVspoof2017_V2_eval.zip
# Data extracted to ../data/raw
# File zip ../data/raw\ASVspoof2017_V2_eval.zip removed

# %% [markdown]
# # Download Labels of Data ASVspoof 2017

# %% [markdown]
# ## 0. Libraries

# %%
import os
import requests
import zipfile

# %% [markdown]
# ## 1. Get setup

# %%
# Base path to store the data
DATA_DIR = "../data/annotations"  # Ensure this folder exists

# URL of the labels data set
TRAINING_URL = "https://datashare.ed.ac.uk/bitstream/handle/10283/3055/protocol_V2.zip?sequence=9&isAllowed=y"
ARCHIVE_NAME = "Protocol.zip"

# %% [markdown]
# ## 2. Functions to download and extract data

# %%
# Function to download the file
def download_file(url, dest_folder):
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
    
    file_path = os.path.join(dest_folder, ARCHIVE_NAME)
    
    # Download the file if it doesn't exist already
    if not os.path.exists(file_path):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(file_path, 'wb') as f:
            f.write(response.content)
        print(f"Download complete: {file_path}")
    else:
        print(f"The file already exists at {file_path}")
    
    return file_path

# %%
# Function to extract the zip file
def extract_zip(archive_path, extract_to):
    with zipfile.ZipFile(archive_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
        print(f"Data extracted to {extract_to}")
    
    os.remove(archive_path)
    print(f"File zip {archive_path} removed")

# %% [markdown]
# ## 3. Download and extract the data

# %%
# Download and extract the training set
archive_path = download_file(TRAINING_URL, DATA_DIR)
extract_zip(archive_path, DATA_DIR)
# Out:
# ...
# Download complete: ../data/annotations\Protocol.zip
# Data extracted to ../data/annotations
# File zip ../data/annotations\Protocol.zip removed
